# %%
import pandas as pd
list_sr = pd.Series ()

# %%
list_sr.name

# %%
import numpy as np
sr1 = pd.Series(dtype=int)

# %%
sr3.index

# %%
score = [['정약용', 70, 80, 100 ]]

# %%
score_df

# %%
score_dict = {
    
}

# %%
New Df = score

# %%
score_df[1:]

# %%
score_df[1:][['이름', '총점']]

# %%
score_df[(score_df.국어 > 80)] [(score_df.영어 < 90)]

# %%
sample_df = pd.read_
